# %%
#Integer example
age = 35
type(age)
# Out:
# int

# %%
#floating point type
height = 31.5
type(height)
# Out:
# float

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
is_true = True
type(is_true)
# Out:
# bool

# %%
a = 10 
b = 10 
a == b
# Out:
# True

# %%
type (a == b)
# Out:
# bool

# %%
# common errors 
result = "Hello" + str(5)
print(result)
# Out:
# Hello5
