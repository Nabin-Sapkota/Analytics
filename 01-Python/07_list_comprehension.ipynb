# %%
# new_list = [expression for item in old_list if condition]

# %%
claim_amounts = [1200.50, 340.00, 8750.25, 125.00, 4300.75]
diagnoses = ["I10", "E11.9", "J18.9", "I21.9", "S06.0"]
patients = ["John Smith", "Maria Garcia", "James Lee", "Priya Patel"]
high_cost_claims = []
for amount in claim_amounts: 
    if amount > 1000:
        high_cost_claims.append(amount)

# %%
# filter claims over $1000 
from importlib.metadata import diagnose


high_cost_claims = [amount for amount in claim_amounts if amount > 1000]
print(high_cost_claims) 

# Convert all claim amounts apply 10% insurance adjustment
adjusted_claims = [amount * 0.99 for amount in claim_amounts]

# Extract only cardiovascular ICD-10 codes (they start with 'I')
cardio_codes = [code for code in diagnoses if code.startswith('I')]
print(cardio_codes)

# Uppercase all patient names 
upper_names = [name.upper() for name in patients]
