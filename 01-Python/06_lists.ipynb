# %%
# A list of patients admitted today
patients = ["John Smith", "Maria", "James", "Priya Patel"]

# A list of claim amounts (In USD)
claim_amounts = [1200.50, 340.00, 8750.25, 125.00, 4300.75]

# A list of ICD-10 diagnosis codes 
diagnoses= ["I10", "E11.9", "J18.9", "I21.9", "S06.0"]

# %%
# The operations you'll use the most 

# Indexing - first patient (index starts at 0)
print(patients[0])

# slicing - first three patients
print(patients[0:3])

# Add a new patient
patients.append("Robert Johnson")

# remove a discharged patient
patients.remove("James Lee")

# Length - how many patients 
print(len(patients))

# check if a diaagnosis exists

if "I10" in diagnoses: 
    print("Hypertension case found") 

# sort claim amounts
claim_amounts.sort()
print(claim_amounts) # lowest to highest
