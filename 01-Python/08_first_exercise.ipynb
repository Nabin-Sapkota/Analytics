# %%
codes = ["I10", "E11.9", "J18.9", "I21.9", "S06.0", "E10.9", "I25.10", "J45.901"]

cardiac_codes = [code for code in codes if code.startswith("I")]
diabetic_codes = [code for code in codes if code.startswith("E")]
print(diabetic_codes + "\n" + cardiac_codes)

# %%
# ── Healthcare Python – Lesson 1 ──────────────────────────

# Q1 – ICD-10 code filtering
codes = ["I10", "E11.9", "J18.9", "I21.9", "S06.0", "E10.9", "I25.10", "J45.901"]

cardiac_codes  = [code for code in codes if code.startswith("I")]
diabetes_codes = [code for code in codes if code.startswith("E")]  # fill this

print("Cardiac codes:", cardiac_codes)
print("Cardiac count:", len(cardiac_codes))
print("Diabetes codes:", diabetes_codes)
print("Diabetes count:", len(diabetes_codes))

# Q2 – High cost claim flagging
claims = [450.00, 12000.00, 320.50, 8900.25, 75.00, 5400.00, 210.75]

flagged_claims = [amount for amount in claims if amount > 5000]  # fill this

print("Flagged claims:", flagged_claims)
print("Flagged total: $", sum(flagged_claims))
